# %%
import pandas as pd

# %% [markdown]
# # Data sources:
#
# https://www.kaggle.com/datasets/shuyangli94/food-com-recipes-and-user-interactions?select=RAW_recipes.csv
#
# https://www.kaggle.com/datasets/shuyangli94/foodcom-recipes-with-search-terms-and-tags
#
# https://www.kaggle.com/datasets/irkaal/foodcom-recipes-and-reviews

# %% [markdown]
# # Read data

# %% [markdown]
# Download all data sources and unpack then in src directory

# %%
# read cvs file "PP_recipes.csv" and print first 10 rows
raw_recipes = pd.read_csv('src/RAW_recipes.csv')
raw_recipes = raw_recipes[['id', 'name', 'minutes', 'submitted', 'tags', 'n_steps', 'steps', 'description']]
raw_recipes.head(2)
# Out:
#        id                                        name  minutes   submitted  \
# 0  137739  arriba   baked winter squash mexican style       55  2005-09-16
# 1   31490            a bit different  breakfast pizza       30  2002-06-17
#
#                                                 tags  n_steps  \
# 0  ['60-minutes-or-less', 'time-to-make', 'course...       11
# 1  ['30-minutes-or-less', 'time-to-make', 'course...        9
#
#                                                steps  \
# 0  ['make a choice and proceed with recipe', 'dep...
# 1  ['preheat oven to 425 degrees f', 'press dough...
#
#                                          description
# 0  autumn is my favorite time of year to cook! th...
# 1  this recipe calls for the crust to be prebaked...

# %%
recipes_with_ingredients = pd.read_csv('src/recipes_w_search_terms.csv')
recipes_with_ingredients = recipes_with_ingredients[['id', 'ingredients_raw_str', 'ingredients']]
recipes_with_ingredients.head(2)
# Out:
#        id                                ingredients_raw_str  \
# 0   96313  ["4   cups    water","1   cup   uncooked old f...
# 1  232037  ["1   medium    onion, chopped coarse ","1   m...
#
#                                          ingredients
# 0  ['water', 'grits', 'salt', 'cheddar cheese', '...
# 1  ['onion', 'red bell pepper', 'garlic cloves', ...

# %%
recipes_big = pd.read_parquet('src/recipes_with_imgs.parquet', engine='fastparquet')
recipes_big = recipes_big[['RecipeId', 'AuthorId', 'AuthorName', 'ReviewCount']]
recipes_big.head(2)
# Out:
#    RecipeId  AuthorId AuthorName  ReviewCount
# 0      38.0      1533     Dancer          4.0
# 1      39.0      1567   elly9812          1.0

# %%
recipes_tokenized = pd.read_csv('src/PP_recipes.csv')
recipes_tokenized = recipes_tokenized[['id', 'calorie_level', 'ingredient_ids']]
recipes_tokenized.head(2)
# Out:
#        id  calorie_level                                     ingredient_ids
# 0  424415              0                      [389, 7655, 6270, 1527, 3406]
# 1  146223              0  [2683, 4969, 800, 5298, 840, 2499, 6632, 7022,...

# %% [markdown]
# # Prepare recipes base

# %%
# merge interactions_count with recipes based in id
recipes_full = pd.merge(raw_recipes, recipes_with_ingredients, left_on='id', right_on='id', how='left')
# merge interactions_count with recipes based in id
recipes_full = pd.merge(recipes_full, recipes_tokenized, left_on='id', right_on='id', how='left')
# merge with recipes_big
recipes_full = pd.merge(recipes_full, recipes_big, left_on='id', right_on='RecipeId', how='left')

recipes_full = recipes_full.dropna(subset=['AuthorId', 'AuthorName'])

# %%
# sort recipes by review count and take top 1000
base_recipes = recipes_full.sort_values(by=['ReviewCount'], ascending=False)
base_recipes.dropna()

# drop recipes where ingredient_ids are nan
base_recipes = base_recipes.dropna(subset=['ingredient_ids'])

base_recipes = base_recipes.head(5000)

base_recipes
# Out:
#             id                                               name  minutes  \
# 22168     2886                                  best banana bread       65
# 213826   27208                         to die for crock pot roast      545
# 66687    89204  crock pot chicken with black beans   cream cheese      243
# 62431    39087                         creamy cajun chicken pasta       25
# 22388    67256   best ever banana cake with cream cheese frosting       75
# ...        ...                                                ...      ...
# 123547  442185                          light and fluffy biscuits       30
# 92715   348549   glazed carrots with maple syrup and sesame seeds       17
# 227203   54787  whoopie pies   the real deal   lancaster co  r...       38
# 34388    17449              campbell s chicken   broccoli alfredo       20
# 100373   26233            ground beef and garbanzo bean casserole       60
#
#          submitted                                               tags  \
# 22168   1999-09-26  ['time-to-make', 'course', 'main-ingredient', ...
# 213826  2002-05-03  ['weeknight', 'time-to-make', 'course', 'main-...
# 66687   2004-04-16  ['time-to-make', 'course', 'main-ingredient', ...
# 62431   2002-09-02  ['30-minutes-or-less', 'time-to-make', 'course...
# 22388   2003-07-24  ['weeknight', 'time-to-make', 'course', 'main-...
# ...            ...                                                ...
# 123547  2010-11-16  ['30-minutes-or-less', 'time-to-make', 'course...
# 92715   2009-01-09  ['30-minutes-or-less', 'time-to-make', 'course...
# 227203  2003-02-24  ['60-minutes-or-less', 'time-to-make', 'course...
# 34388   2002-01-18  ['30-minutes-or-less', 'time-to-make', 'course...
# 100373  2002-04-24  ['lactose', '60-minutes-or-less', 'time-to-mak...
#
#         n_steps                                              steps  \
# 22168        13  ['remove odd pots and pans from oven', 'prehea...
# 213826        7  ['place beef roast in crock pot', 'mix the dri...
# 66687         5  ['take 4-5 frozen , yes , frozen , boneless ch...
# 62431         4  ['place chicken and cajun seasoning in a bowl ...
# 22388        18  ['preheat oven to 275f', 'grease and flour a 9...
# ...         ...                                                ...
# 123547       11  ['combine the flour , salt , baking powder and...
# 92715         4  ['put the carrots into a medium pan with half ...
# 227203       14  ['cream shortening , sugar and eggs', 'add van...
# 34388         7  ['cook linguine according to package direction...
# 100373        8  ['preheat oven to 350f', 'brown beef with onio...
#
#                                               description  \
# 22168   you'll never need another banana bread recipe ...
# 213826  amazing flavor, and so simple! no salt needed ...
# 66687   i love this crock-pot chicken recipe for two r...
# 62431   n'awlin's style of chicken with an updated alf...
# 22388   this is one of (if not) the best banana cake i...
# ...                                                   ...
# 123547  if you like biscuits, i am sure you will like ...
# 92715   wanting a quick carrot dish last night, i turn...
# 227203  mmmmmmmmmmmmmmmmm! if you've never had a whoop...
# 34388                                                 NaN
# 100373  came from the better home and garden's meat st...
#
#                                       ingredients_raw_str  \
# 22168   ["1/2  cup    butter, softened ","1   cup    g...
# 213826  ["1 (4 -5   lb)    beef roast, any kind ","1 (...
# 66687   ["4 -5       boneless chicken breasts, frozen ...
# 62431   ["2       boneless skinless chicken breast hal...
# 22388   ["1 1/2  cups    bananas, mashed, ripe ","2   ...
# ...                                                   ...
# 123547  ["4   cups    all-purpose flour","1   teaspoon...
# 92715   ["1   lb    carrot, peeled and cut into batons...
# 227203  ["1   cup    oil","2   cups    brown sugar","4...
# 34388   ["8   ounces    linguine","1   cup   fresh, fr...
# 100373  ["1   lb    ground beef","1   cup   chopped on...
#
#                                               ingredients  calorie_level  \
# 22168   ['butter', 'granulated sugar', 'eggs', 'banana...            1.0
# 213826  ['beef roast', 'brown gravy mix', 'dried itali...            1.0
# 66687   ['boneless chicken breasts', 'black beans', 'c...            2.0
# 62431   ['boneless skinless chicken breast halves', 'l...            2.0
# 22388   ['bananas', 'lemon juice', 'flour', 'baking so...            2.0
# ...                                                   ...            ...
# 123547  ['all-purpose flour', 'salt', 'baking powder',...            1.0
# 92715   ['carrot', 'butter', 'honey', 'salt', 'water',...            0.0
# 227203  ['oil', 'brown sugar', 'eggs', 'flour', 'salt'...            2.0
# 34388   ['linguine', 'broccoli florets', 'butter', 'bo...            2.0
# 100373  ['ground beef', 'onion', 'garlic cloves', 'gar...            1.0
#
#                                            ingredient_ids  RecipeId  \
# 22168         [840, 3355, 2499, 342, 63, 335, 6270, 7449]    2886.0
# 213826                       [469, 784, 2200, 2200, 7655]   27208.0
# 66687                       [1252, 553, 1803, 6265, 1910]   89204.0
# 62431   [1254, 4416, 905, 840, 6335, 3670, 6926, 6270,...   39087.0
# 22388   [342, 4253, 2683, 335, 6270, 840, 6906, 2499, ...   67256.0
# ...                                                   ...       ...
# 123547             [63, 6270, 332, 6906, 855, 2499, 4717]  442185.0
# 92715                 [1093, 840, 3723, 6270, 7655, 6416]  348549.0
# 227203  [4987, 800, 2499, 2683, 6270, 335, 1584, 4717,...   54787.0
# 34388      [4416, 761, 840, 1252, 1920, 4717, 5180, 5319]   17449.0
# 100373  [3484, 5010, 3203, 3179, 7233, 7655, 2320, 627...   26233.0
#
#          AuthorId       AuthorName  ReviewCount
# 22168      1762.0          lkadlec       2273.0
# 213826    28201.0           yooper       1692.0
# 66687    137839.0     Jen Santiago       1657.0
# 62431     30534.0            Lorac       1586.0
# 22388     82367.0         Rhonda J       1409.0
# ...           ...              ...          ...
# 123547  1728457.0       skeptic777         25.0
# 92715    323186.0  Karen Elizabeth         25.0
# 227203    41706.0           WJKing         25.0
# 34388     20754.0        RecipeNut         25.0
# 100373    37640.0    Angela Curtis         25.0
#
# [5000 rows x 16 columns]

# %% [markdown]
# # Ingredients table

# %%
ingredients = pd.read_pickle('src/ingr_map.pkl')

# create new ingredients table data, that stores only processed and id columns off current ingredients data
ingredients_processed = ingredients[['id', 'replaced']]
ingredients_processed.columns = ['id', 'ingredient_name']

# remove repetitions in ingredients_processed
ingredients_processed = ingredients_processed.drop_duplicates()
# save processed ingredients to csv file
ingredients_processed.to_csv('result/ingredients.csv', index=False)

ingredients_processed
# Out:
#          id                             ingredient_name
# 0      4308                                     lettuce
# 42     2744  french vanilla pudding and pie filling mix
# 43     6843                      stove top stuffing mix
# 45     1910                                cream cheese
# 86     1168                                     cheddar
# ...     ...                                         ...
# 11654  6702                                     soybean
# 11655  3318                                       goose
# 11656    47                                      ajwain
# 11657   750                                     brinjal
# 11658  4061                                       khoya
#
# [8023 rows x 2 columns]

# %% [markdown]
# # Recipes-ingredients table

# %%
import ast
# create empty pandas dataframe
recipes_ingredients = pd.DataFrame()

to_drop = []
for index, row in base_recipes.iterrows():
    try:
        ingredients_raw = ast.literal_eval(row['ingredients_raw_str'])
        ingredients_ids = ast.literal_eval(row['ingredient_ids'])
        ingredients_names = ast.literal_eval(row['ingredients'])
    except:
        to_drop.append(index)
        continue

    if len(ingredients_names) > len(ingredients_ids):
        ingredients_names = ingredients_names[:len(ingredients_ids)]
    elif len(ingredients_names) < len(ingredients_ids):
        ingredients_ids = ingredients_ids[:len(ingredients_names)]

    if len(ingredients_raw) > len(ingredients_names):
        ingredients_raw = ingredients_raw[:len(ingredients_names)]
    elif len(ingredients_raw) < len(ingredients_names):
        ingredients_names = ingredients_names[:len(ingredients_raw)]

    ingredients_quantity = []
    for i, ingredient_raw in enumerate(ingredients_raw):
        words = ingredient_raw.split()
        if len(words) == 0:
            ingredients_quantity.append('')
            continue
        
        quantity = words[0]
        words = words[1:]

        
        if (len(words) > 0):
            if '(' in words[0]:
                while ')' not in words[0]:
                    quantity += ' ' + words[0]
                    words = words[1:]
                quantity += ' ' + words[0]
                words = words[1:]
        
        # add some possible fractions

        if (len(words) > 0):
            if any(char.isdigit() for char in words[0]):
                quantity += ' ' + words[0]
                words = words[1:]

        if (len(words) > 0):
            if '(' in words[0]:
                while ')' not in words[0]:
                    quantity += ' ' + words[0]
                    words = words[1:]
                quantity += ' ' + words[0]
                words = words[1:]
        
        # add measurement unit
        if (len(words) > 0):
            if words[0] != ingredients_names[i].split(' ')[0]:
                quantity += ' ' + words[0]
            
        ingredients_quantity.append(quantity)

    # create dataframe with names and id's 
    ingredients_array = pd.DataFrame({'ingredient_quantity': ingredients_quantity, 'ingredient_id': ingredients_ids})

    # add row id column to tags_array
    ingredients_array['recipe_id'] = row['id']

    # add row to recipes_tags dataframe
    recipes_ingredients = pd.concat([recipes_ingredients, ingredients_array], ignore_index=True)

# drop recipes with index in to_drop
base_recipes = base_recipes.drop(to_drop)

# change the order of columns in recipes_ingredients
recipes_ingredients = recipes_ingredients[['recipe_id', 'ingredient_quantity', 'ingredient_id']]

recipes_ingredients.to_csv('result/recipes_ingredients.csv', index=False)
print(len(to_drop), len(base_recipes))
recipes_ingredients.head(2)
# Out:
# 88 4912
#    recipe_id ingredient_quantity  ingredient_id
# 0       2886             1/2 cup            840
# 1       2886               1 cup           3355

# %% [markdown]
# # Tags table

# %%
import ast
# create empty pandas dataframe
tags = pd.DataFrame()

# iterate for every row in recipes_with_interactions_1
for index, row in base_recipes.iterrows():
    tags_array = ast.literal_eval(row['tags'])
    # add tags to tags dataframe
    tags = pd.concat([tags, pd.DataFrame(tags_array)], ignore_index=True)

# remove repetitions in tags
tags = tags.drop_duplicates()
# name first column in tags "tag_name"
tags.columns = ['tag_name']
tags['id'] = tags.index

tags = tags[['id', 'tag_name']]
# add id column to tags

tags.to_csv('result/tags.csv', index=False)
tags.head(2)
# Out:
#    id      tag_name
# 0   0  time-to-make
# 1   1        course

# %% [markdown]
# # Recipes-tags table

# %%
# create empty pandas dataframe
recipes_tags = pd.DataFrame()

# iterate for every row in recipes_with_interactions_1
for index, row in base_recipes.iterrows():
    tags_array = ast.literal_eval(row['tags'])

    # find tag id for every tag name in tags_array
    tags_ids = tags[tags['tag_name'].isin(tags_array)]['id'].values

    tags_ids_df = pd.DataFrame(tags_ids, columns=['tag_id'])

    # add row id column to tags_array
    tags_ids_df['recipe_id'] = row['id']

    # add row to recipes_tags dataframe
    recipes_tags = pd.concat([recipes_tags, tags_ids_df], ignore_index=True)

# change the order of columns in recipes_tags
recipes_tags = recipes_tags[['recipe_id', 'tag_id']]
recipes_tags.to_csv('result/recipes_tags.csv', index=False)

recipes_tags.head(2)
# Out:
#    recipe_id  tag_id
# 0       2886       0
# 1       2886       1

# %% [markdown]
# # Recipes-steps table

# %%
recipes_steps = pd.DataFrame()

for index, row in base_recipes.iterrows():
    steps = ast.literal_eval(row['steps'])
    
    # create dataframe with names and id's 
    steps = pd.DataFrame(steps, columns=['step'])

    # add row id column to tags_array
    steps['recipe_id'] = row['id']

    # add row to recipes_tags dataframe
    recipes_steps = pd.concat([recipes_steps, steps], ignore_index=True)

# change the order of columns in recipes_ingredients
recipes_steps = recipes_steps[['recipe_id', 'step']]

recipes_steps.to_csv('result/recipes_steps.csv', index=False)
recipes_steps
# Out:
#        recipe_id                                         step
# 0           2886           remove odd pots and pans from oven
# 1           2886                    preheat oven to 350 / 180
# 2           2886              cream together butter and sugar
# 3           2886                 add eggs and crushed bananas
# 4           2886                                 combine well
# ...          ...                                          ...
# 43435      26233  stir in everything else and heat to boiling
# 43436      26233   put in a 1 1 / 2 quart casserole and cover
# 43437      26233                          bake for 45 minutes
# 43438      26233                            remove bay leaves
# 43439      26233              be sure and stir before serving
#
# [43440 rows x 2 columns]

# %% [markdown]
# # Users table

# %%
# find distinct contributor_id in recipes_table
users = base_recipes[['AuthorId', 'AuthorName']].drop_duplicates()

# change the name of the first column "id"
users.columns = ['id', 'nickname']

# add email column which is equal to id
users['email'] = users['nickname'].replace(" ", "") + '@unknown.com'
users['password'] = 'password'

users.to_csv('result/users.csv', index=False)
users
# Out:
#                id          nickname                         email  password
# 22168      1762.0           lkadlec           lkadlec@unknown.com  password
# 213826    28201.0            yooper            yooper@unknown.com  password
# 66687    137839.0      Jen Santiago      Jen Santiago@unknown.com  password
# 62431     30534.0             Lorac             Lorac@unknown.com  password
# 22388     82367.0          Rhonda J          Rhonda J@unknown.com  password
# ...           ...               ...                           ...       ...
# 225193   353491.0  Clean Plate Club  Clean Plate Club@unknown.com  password
# 99246     47579.0             Peeps             Peeps@unknown.com  password
# 205436    58552.0         NHNichole         NHNichole@unknown.com  password
# 6247     135566.0         LainieBug         LainieBug@unknown.com  password
# 123547  1728457.0        skeptic777        skeptic777@unknown.com  password
#
# [1793 rows x 4 columns]

# %% [markdown]
# # Recipes table

# %%
recipes_table = base_recipes.drop(['steps', 'ingredients', 'ingredient_ids', 'ingredients_raw_str', 'tags', 'RecipeId', 'n_steps', 'AuthorName'], axis=1)

# capitalize descriptions
recipes_table['description'] = recipes_table['description'].str.capitalize()

# change column name call ReviewCount to reactions
recipes_table = recipes_table.rename(columns={'ReviewCount': 'reactions'})

recipes_table.to_csv('result/recipes.csv', index=False)

recipes_table
# Out:
#             id                                               name  minutes  \
# 22168     2886                                  best banana bread       65
# 213826   27208                         to die for crock pot roast      545
# 66687    89204  crock pot chicken with black beans   cream cheese      243
# 62431    39087                         creamy cajun chicken pasta       25
# 22388    67256   best ever banana cake with cream cheese frosting       75
# ...        ...                                                ...      ...
# 123547  442185                          light and fluffy biscuits       30
# 92715   348549   glazed carrots with maple syrup and sesame seeds       17
# 227203   54787  whoopie pies   the real deal   lancaster co  r...       38
# 34388    17449              campbell s chicken   broccoli alfredo       20
# 100373   26233            ground beef and garbanzo bean casserole       60
#
#          submitted                                        description  \
# 22168   1999-09-26  You'll never need another banana bread recipe ...
# 213826  2002-05-03  Amazing flavor, and so simple! no salt needed ...
# 66687   2004-04-16  I love this crock-pot chicken recipe for two r...
# 62431   2002-09-02  N'awlin's style of chicken with an updated alf...
# 22388   2003-07-24  This is one of (if not) the best banana cake i...
# ...            ...                                                ...
# 123547  2010-11-16  If you like biscuits, i am sure you will like ...
# 92715   2009-01-09  Wanting a quick carrot dish last night, i turn...
# 227203  2003-02-24  Mmmmmmmmmmmmmmmmm! if you've never had a whoop...
# 34388   2002-01-18                                                NaN
# 100373  2002-04-24  Came from the better home and garden's meat st...
#
#         calorie_level   AuthorId  reactions
# 22168             1.0     1762.0     2273.0
# 213826            1.0    28201.0     1692.0
# 66687             2.0   137839.0     1657.0
# 62431             2.0    30534.0     1586.0
# 22388             2.0    82367.0     1409.0
# ...               ...        ...        ...
# 123547            1.0  1728457.0       25.0
# 92715             0.0   323186.0       25.0
# 227203            2.0    41706.0       25.0
# 34388             2.0    20754.0       25.0
# 100373            1.0    37640.0       25.0
#
# [4912 rows x 8 columns]

# %%
# find distinct contributor_id in recipes_table
import json
import requests
from tqdm import tqdm

users = base_recipes[['AuthorId', 'AuthorName']].drop_duplicates()


# change the name of the first column "id"
users.columns = ['id', 'username']

users['username'] = users['username'].str.replace(" ", "")

# add email column which is equal to id
users['email'] = users['username'] + '@unknown.com'
users['password'] = 'pass' + users['username']

# for each row send post request to /api/users and store the response in users_table
users_table = pd.DataFrame()
for index, row in users.iterrows():
    # change request dat to json string
    request_data = json.dumps({ 'email': row['email'] + "tmp", 'password': row['password'], 'username': row['username'] })
    response = requests.post('http://127.0.0.1:8000/users/', data=request_data, 
    headers={'Content-Type': 'application/json', 'Accept': 'application/json'})
    
    users_table = users_table.append(pd.DataFrame({'local_id': row['id'], 'api_id': response.json().get('id')}, index=[0]))
# Out:
# 0it [00:00, ?it/s]/tmp/ipykernel_686168/3556674751.py:26: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   users_table = users_table.append(pd.DataFrame({'local_id': row['id'], 'api_id': response.json().get('id')}, index=[0]))
# 1it [00:00,  2.61it/s]/tmp/ipykernel_686168/3556674751.py:26: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   users_table = users_table.append(pd.DataFrame({'local_id': row['id'], 'api_id': response.json().get('id')}, index=[0]))
# 2it [00:00,  2.31it/s]/tmp/ipykernel_686168/3556674751.py:26: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   users_table = users_table.append(pd.DataFrame({'local_id': row['id'], 'api_id': response.json().get('id')}, index=[0]))
# 3it [00:01,  2.48it/s]/tmp/ipykernel_686168/3556674751.py:26: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   users_table = users_table.append(pd.DataFrame({'local_id': row['id'], 'api_id': response.json().get('id')}, index=[0]))
# 4it [00:01,  2.57it/s]/tmp/ipykernel_686168/3556674751.py:26: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   users_table = users_table.append(pd.DataFrame({'local_id': row['id'], 'api_id': response.json().get('id')}, index=[0]))
# 5it [00:01,  2.62it/s]/tmp/ipykernel_686168/3556674751.py:26: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   users_table = users_table.append(pd.DataFrame({'local_id': row['id'], 'api_id': response.json().get('id')}, index=[0]))
# 6it [00:02,  2.66it/s]/tmp/ipykernel_686168/3556674751.py:26: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   users_table = users_table.append(pd.DataFrame({'local_id': row['id'], 'api_id': response.json().get('id')}, index=[0]))
# 7it [00:02,  2.69it/s]/tmp/ipykernel_686168/3556674751.py:26: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   users_table = users_table.append(pd.DataFrame({'local_id': row['id'], 'api_id': response.json().get('id')}, index=[0]))
# 8it [00:03,  2.70it/s]/tmp/ipykernel_686168/3556674751.py:26: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   users_table = users_table.append(pd.DataFrame({'local_id': row['id'], 'api_id': response.json().get('id')}, index=[0]))
# 9it [00:03,  2.74it/s]/tmp/ipykernel_686168/3556674751.py:26: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   users_table = users_table.append(pd.DataFrame({'local_id': row['id'], 'api_id': response.json().get('id')}, index=[0]))
# 10it [00:03,  2.78it/s]/tmp/ipykernel_686168/3556674751.py:26: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   users_table = users_table.append(pd.DataFrame({'local_id': row['id'], 'api_id': response.json().get('id')}, index=[0]))
# 11it [00:04,  2.78it/s]/tmp/ipykernel_686168/3556674751.py:26: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   users_table = users_table.append(pd.DataFrame({'local_id': row['id'], 'api_id': response.json().get('id')}, index=[0]))
# 12it [00:04,  2.76it/s]/tmp/ipykernel_686168/3556674751.py:26: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   users_table = users_table.append(pd.DataFrame({'local_id': row['id'], 'api_id': response.json().get('id')}, index=[0]))
# 13it [00:04,  2.75it/s]/tmp/ipykernel_686168/3556674751.py:26: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   users_table = users_table.append(pd.DataFrame({'local_id': row['id'], 'api_id': response.json().get('id')}, index=[0]))
# 14it [00:05,  2.68it/s]/tmp/ipykernel_686168/3556674751.py:26: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   users_table = users_table.append(pd.DataFrame({'local_id': row['id'], 'api_id': response.json().get('id')}, index=[0]))
# 15it [00:05,  2.67it/s]/tmp/ipykernel_686168/3556674751.py:26: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   users_table = users_table.append(pd.DataFrame({'local_id': row['id'], 'api_id': response.json().get('id')}, index=[0]))
# 16it [00:05,  2.70it/s]/tmp/ipykernel_686168/3556674751.py:26: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   users_table = users_table.append(pd.DataFrame({'local_id': row['id'], 'api_id': response.json().get('id')}, index=[0]))
# 17it [00:06,  2.72it/s]/tmp/ipykernel_686168/3556674751.py:26: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   users_table = users_table.append(pd.DataFrame({'local_id': row['id'], 'api_id': response.json().get('id')}, index=[0]))
# 18it [00:06,  2.76it/s]/tmp/ipykernel_686168/3556674751.py:26: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   users_table = users_table.append(pd.DataFrame({'local_id': row['id'], 'api_id': response.json().get('id')}, index=[0]))
# 19it [00:07,  2.77it/s]/tmp/ipykernel_686168/3556674751.py:26: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   users_table = users_table.append(pd.DataFrame({'local_id': row['id'], 'api_id': response.json().get('id')}, index=[0]))
# 20it [00:07,  2.75it/s]/tmp/ipykernel_686168/3556674751.py:26: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   users_table = users_table.append(pd.DataFrame({'local_id': row['id'], 'api_id': response.json().get('id')}, index=[0]))
# 21it [00:07,  2.69it/s]/tmp/ipykernel_686168/3556674751.py:26: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   users_table = users_table.append(pd.DataFrame({'local_id': row['id'], 'api_id': response.json().get('id')}, index=[0]))
# 22it [00:08,  2.68it/s]/tmp/ipykernel_686168/3556674751.py:26: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   users_table = users_table.append(pd.DataFrame({'local_id': row['id'], 'api_id': response.json().get('id')}, index=[0]))
# 23it [00:08,  2.67it/s]/tmp/ipykernel_686168/3556674751.py:26: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   users_table = users_table.append(pd.DataFrame({'local_id': row['id'], 'api_id': response.json().get('id')}, index=[0]))
# 24it [00:08,  2.66it/s]/tmp/ipykernel_686168/3556674751.py:26: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   users_table = users_table.append(pd.DataFrame({'local_id': row['id'], 'api_id': response.json().get('id')}, index=[0]))
# 25it [00:09,  2.69it/s]/tmp/ipykernel_686168/3556674751.py:26: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   users_table = users_table.append(pd.DataFrame({'local_id': row['id'], 'api_id': response.json().get('id')}, index=[0]))
# 26it [00:09,  2.71it/s]/tmp/ipykernel_686168/3556674751.py:26: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   users_table = users_table.append(pd.DataFrame({'local_id': row['id'], 'api_id': response.json().get('id')}, index=[0]))
# 27it [00:10,  2.72it/s]/tmp/ipykernel_686168/3556674751.py:26: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   users_table = users_table.append(pd.DataFrame({'local_id': row['id'], 'api_id': response.json().get('id')}, index=[0]))
# 28it [00:10,  2.71it/s]/tmp/ipykernel_686168/3556674751.py:26: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   users_table = users_table.append(pd.DataFrame({'local_id': row['id'], 'api_id': response.json().get('id')}, index=[0]))
# 29it [00:10,  2.72it/s]/tmp/ipykernel_686168/3556674751.py:26: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   users_table = users_table.append(pd.DataFrame({'local_id': row['id'], 'api_id': response.json().get('id')}, index=[0]))
# 30it [00:11,  2.72it/s]/tmp/ipykernel_686168/3556674751.py:26: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   users_table = users_table.append(pd.DataFrame({'local_id': row['id'], 'api_id': response.json().get('id')}, index=[0]))
# 31it [00:11,  2.68it/s]/tmp/ipykernel_686168/3556674751.py:26: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   users_table = users_table.append(pd.DataFrame({'local_id': row['id'], 'api_id': response.json().get('id')}, index=[0]))
# 32it [00:11,  2.66it/s]/tmp/ipykernel_686168/3556674751.py:26: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   users_table = users_table.append(pd.DataFrame({'local_id': row['id'], 'api_id': response.json().get('id')}, index=[0]))
# 33it [00:12,  2.68it/s]/tmp/ipykernel_686168/3556674751.py:26: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   users_table = users_table.append(pd.DataFrame({'local_id': row['id'], 'api_id': response.json().get('id')}, index=[0]))
# 34it [00:12,  2.67it/s]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In [36], line 23
#      20 for index, row in tqdm(users.iterrows()):
#      21     # change request dat to json string
#      22     request_data = json.dumps({ 'email': row['email'] + "tmp", 'password': row['password'], 'username': row['username'] })
# ---> 23     response = requests.post('http://127.0.0.1:8000/users/', data=request_data,
#      24     headers={'Content-Type': 'application/json', 'Accept': 'application/json'})
#      26     users_table = users_table.append(pd.DataFrame({'local_id': row['id'], 'api_id': response.json().get('id')}, index=[0]))
#
# File /usr/lib/python3/dist-packages/requests/api.py:119, in post(url, data, json, **kwargs)
#     107 def post(url, data=None, json=None, **kwargs):
#     108     r"""Sends a POST request.
#     109
#     110     :param url: URL for the new :class:`Request` object.
#    (...)
#     116     :rtype: requests.Response
#     117     """
# --> 119     return request('post', url, data=data, json=json, **kwargs)
#
# File /usr/lib/python3/dist-packages/requests/api.py:61, in request(method, url, **kwargs)
#      57 # By using the 'with' statement we are sure the session is closed, thus we
#      58 # avoid leaving sockets open which can trigger a ResourceWarning in some
#      59 # cases, and look like a memory leak in others.
#      60 with sessions.Session() as session:
# ---> 61     return session.request(method=method, url=url, **kwargs)
#
# File /usr/lib/python3/dist-packages/requests/sessions.py:542, in Session.request(self, method, url, params, data, headers, cookies, files, auth, timeout, allow_redirects, proxies, hooks, stream, verify, cert, json)
#     537 send_kwargs = {
#     538     'timeout': timeout,
#     539     'allow_redirects': allow_redirects,
#     540 }
#     541 send_kwargs.update(settings)
# --> 542 resp = self.send(prep, **send_kwargs)
#     544 return resp
#
# File /usr/lib/python3/dist-packages/requests/sessions.py:655, in Session.send(self, request, **kwargs)
#     652 start = preferred_clock()
#     654 # Send the request
# --> 655 r = adapter.send(request, **kwargs)
#     657 # Total elapsed time of the request (approximately)
#     658 elapsed = preferred_clock() - start
#
# File /usr/lib/python3/dist-packages/requests/adapters.py:439, in HTTPAdapter.send(self, request, stream, timeout, verify, cert, proxies)
#     437 try:
#     438     if not chunked:
# --> 439         resp = conn.urlopen(
#     440             method=request.method,
#     441             url=url,
#     442             body=request.body,
#     443             headers=request.headers,
#     444             redirect=False,
#     445             assert_same_host=False,
#     446             preload_content=False,
#     447             decode_content=False,
#     448             retries=self.max_retries,
#     449             timeout=timeout
#     450         )
#     452     # Send the request.
#     453     else:
#     454         if hasattr(conn, 'proxy_pool'):
#
# File /usr/lib/python3/dist-packages/urllib3/connectionpool.py:699, in HTTPConnectionPool.urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, **response_kw)
#     696     self._prepare_proxy(conn)
#     698 # Make the request on the httplib connection object.
# --> 699 httplib_response = self._make_request(
#     700     conn,
#     701     method,
#     702     url,
#     703     timeout=timeout_obj,
#     704     body=body,
#     705     headers=headers,
#     706     chunked=chunked,
#     707 )
#     709 # If we're going to release the connection in ``finally:``, then
#     710 # the response doesn't need to know about the connection. Otherwise
#     711 # it will also try to release it and we'll have a double-release
#     712 # mess.
#     713 response_conn = conn if not release_conn else None
#
# File /usr/lib/python3/dist-packages/urllib3/connectionpool.py:445, in HTTPConnectionPool._make_request(self, conn, method, url, timeout, chunked, **httplib_request_kw)
#     440             httplib_response = conn.getresponse()
#     441         except BaseException as e:
#     442             # Remove the TypeError from the exception chain in
#     443             # Python 3 (including for exceptions like SystemExit).
#     444             # Otherwise it looks like a bug in the code.
# --> 445             six.raise_from(e, None)
#     446 except (SocketTimeout, BaseSSLError, SocketError) as e:
#     447     self._raise_timeout(err=e, url=url, timeout_value=read_timeout)
#
# File <string>:3, in raise_from(value, from_value)
#
# File /usr/lib/python3/dist-packages/urllib3/connectionpool.py:440, in HTTPConnectionPool._make_request(self, conn, method, url, timeout, chunked, **httplib_request_kw)
#     437 except TypeError:
#     438     # Python 3
#     439     try:
# --> 440         httplib_response = conn.getresponse()
#     441     except BaseException as e:
#     442         # Remove the TypeError from the exception chain in
#     443         # Python 3 (including for exceptions like SystemExit).
#     444         # Otherwise it looks like a bug in the code.
#     445         six.raise_from(e, None)
#
# File /usr/lib/python3.10/http/client.py:1374, in HTTPConnection.getresponse(self)
#    1372 try:
#    1373     try:
# -> 1374         response.begin()
#    1375     except ConnectionError:
#    1376         self.close()
#
# File /usr/lib/python3.10/http/client.py:318, in HTTPResponse.begin(self)
#     316 # read until we get a non-100 response
#     317 while True:
# --> 318     version, status, reason = self._read_status()
#     319     if status != CONTINUE:
#     320         break
#
# File /usr/lib/python3.10/http/client.py:279, in HTTPResponse._read_status(self)
#     278 def _read_status(self):
# --> 279     line = str(self.fp.readline(_MAXLINE + 1), "iso-8859-1")
#     280     if len(line) > _MAXLINE:
#     281         raise LineTooLong("status line")
#
# File /usr/lib/python3.10/socket.py:705, in SocketIO.readinto(self, b)
#     703 while True:
#     704     try:
# --> 705         return self._sock.recv_into(b)
#     706     except timeout:
#     707         self._timeout_occurred = True
#
# KeyboardInterrupt:

# %%
# join users_table with users
users = users.merge(users_table, left_on='id', right_on='local_id')
users
# Out:
#        id username                email     password  local_id_x  api_id_x  \
# 0  1762.0  lkadlec  lkadlec@unknown.com  passlkadlec      1762.0         5
#
#    local_id_y  api_id_y  local_id  api_id
# 0      1762.0         5    1762.0       5
